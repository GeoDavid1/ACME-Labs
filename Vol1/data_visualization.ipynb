# %% [markdown]
# <h1 align="center"> Python Essentials: Data Visualization.</h1>
#
#     <Name> David Camacho
#     <Class> 002
#     <Date> 11/9/22

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats
import scipy

# %%
plt.rcParams["figure.dpi"] = 300     # Raise figure quality.

# %% [markdown]
# ### Problem 1
#
# The file `anscombe.npy` contains Anscombe’s quartet.
# For each section of the quartet,
# - Plot the data as a scatter plot on the box [0, 20] × [0, 13].
# - Use `scipy.stats.linregress()` to calculate the slope and intercept of the least squares regression line for the data and its correlation coefficient (the first three return values).
# - Plot the least squares regression line over the scatter plot on the domain $x\in[0,20]$.
# - Report (print) the mean and variance in $x$ and $y$, the slope and intercept of the regression line, and the correlation coefficient. Compare these statistics to those of the other sections.
# - Describe how the section is similar to the others and how it is different.

# %%
A = np.load("anscombe.npy")

Q1 = A[0:11, 0:2]
Q2 = A[0:11, 2:4]
Q3 = A[0:11, 4:6]
Q4 = A[0:11, 6:8]


ax1 = plt.subplot(221)
x = Q1[0:11, 0]
y = Q1[0:11, 1]
ax1.plot(x,y, 'o', markersize= 1, alpha = 0.5)
plt.xlim(0,20)
plt.ylim(0,13)

Slope1 = stats.linregress(x,y)[0]
Intercept1 = stats.linregress(x,y)[1]
CorrelationCoefficient1 = stats.linregress(x,y)[2]

Mean1 = np.mean(Q1[0:11, 1])
Var1 = np.var(Q1[0:11, 1])




X1 = np.linspace(0,20,100)
ax1.plot(X1, Slope1*X1 + Intercept1)


ax2 = plt.subplot(222)
x = Q2[0:11, 0]
y = Q2[0:11, 1]
ax2.plot(x,y, 'o', markersize = 1, alpha = 0.5)
plt.xlim(0,20)
plt.ylim(0,13)

Slope2 = stats.linregress(x,y)[0]
Intercept2 = stats.linregress(x,y)[1]
CorrelationCoefficient2 = stats.linregress(x,y)[2]

Mean2 = np.mean(Q2[0:11, 1])
Var2 = np.var(Q2[0:11, 1])


X2 = np.linspace(0,20,100)
ax2.plot(X2, Slope2*X2 + Intercept2)



ax3 = plt.subplot(223)
x = Q3[0:11, 0]
y = Q3[0:11, 1]
ax3.plot(x,y, 'o', markersize = 1, alpha = 0.5)
plt.xlim(0,20)
plt.ylim(0,13)

Slope3 = stats.linregress(x,y)[0]
Intercept3 = stats.linregress(x,y)[1]
CorrelationCoefficient3 = stats.linregress(x,y)[2]

Mean3 = np.mean(Q3[0:11, 1])
Var3 = np.var(Q3[0:11, 1])


X3 = np.linspace(0,20,100)
ax3.plot(X3, Slope3*X3 + Intercept3)


ax4 = plt.subplot(224)
x = Q4[0:11, 0]
y = Q4[0:11, 1]
ax4.plot(x,y, 'o', markersize = 1, alpha = 0.5)
plt.xlim(0,20)
plt.ylim(0,13)

Slope4 = stats.linregress(x,y)[0]
Intercept4 = stats.linregress(x,y)[1]
CorrelationCoefficient4 = stats.linregress(x,y)[2]

Mean4 = np.mean(Q4[0:11, 1])
Var4 = np.var(Q4[0:11, 1])

X4 = np.linspace(0,20,100)
ax4.plot(X4, Slope4*X4 + Intercept4)



print("Mean 1: " + str(Mean1))
print("Variance 1: " + str(Var1))
print("Slope 1: " + str(Slope1))
print("Intercept 1: " + str(Intercept1))
print("Correlation Coefficient 1: " + str(CorrelationCoefficient1))
print(" ")
print("Mean 2: " + str(Mean2))
print("Variance 2: " + str(Var2))
print("Slope 2: " + str(Slope2))
print("Intercept 2: " + str(Intercept2))
print("Correlation Coefficient 2: " + str(CorrelationCoefficient2))
print(" ")
print("Mean 3: " + str(Mean3))
print("Variance 3: " + str(Var3))
print("Slope 3: " + str(Slope3))
print("Intercept 3: " + str(Intercept3))
print("Correlation Coefficient 3: " + str(CorrelationCoefficient3))
print(" ")
print("Mean 4: " + str(Mean4))
print("Variance 4: " + str(Var4))
print("Slope 4: " + str(Slope4))
print("Intercept 4: " + str(Intercept4))
print("Correlation Coefficient 4: " + str(CorrelationCoefficient4))
print(" ")
print("The sections have the same mean, variance, slope, y-intercept, and correlation coefficient")
print("but they have different data points")
# Out:
# Mean 1: 7.500909090909093
# Variance 1: 3.7520628099173554
# Slope 1: 0.5000909090909091
# Intercept 1: 3.0000909090909103
# Correlation Coefficient 1: 0.8164205163448399
#
# Mean 2: 7.50090909090909
# Variance 2: 3.752390082644628
# Slope 2: 0.5000000000000001
# Intercept 2: 3.000909090909089
# Correlation Coefficient 2: 0.816236506000243
#
# Mean 3: 7.5
# Variance 3: 3.747836363636364
# Slope 3: 0.4997272727272729
# Intercept 3: 3.002454545454544
# Correlation Coefficient 3: 0.8162867394895984
#
# Mean 4: 7.500909090909091
# Variance 4: 3.7484082644628103
# Slope 4: 0.4999090909090909
# Intercept 4: 3.0017272727272726
# Correlation Coefficient 4: 0.8165214368885028
#
# The sections have the same mean, variance, slope, y-intercept, and correlation coefficient
# but they have different data points

# %% [markdown]
# ### Problem 2
# The $n + 1$ Bernstein basis polynomials of degree $n$ are defined as follows.
#
# $$b_{n,v}(x) = \binom{n}{v}x^v(1-x)^{n-v},\quad v=0,\ 1,\ \ldots,\ n$$
#
# Plot the first $10$ Bernstein basis polynomials ($n = 0,\ 1,\ 2,\ 3$) as small multiples on the domain $[0, 1] \times [0, 1]$.
# Label the subplots for clarity, adjust tick marks and labels for simplicity, and set the window limits of
# each plot to be the same.
# Consider arranging the subplots so that the rows correspond with $n$ and the columns with $v$.
#
# (Hint: The constant $\binom{n}{v} = \frac{n!}{v!(n-v)!}$ is called the binomial coefficient and can be efficiently computed with `scipy.special.binom()` or `scipy.special.comb()`.)

# %%
def Bernstein(x,v,n):

    Value = scipy.special.comb(n,v)*((x)**v)*((1-x)**(n-v))

    return Value

fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(5)

ax1 = plt.subplot(441)
x = np.linspace(0,1,100)
ax1.plot(x, Bernstein(x,0,0), 'b', lw = 2)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel('x')
plt.ylabel('y')
plt.title("n = 0; v = 0")

ax2 = plt.subplot(445)
x = np.linspace(0,1,100)
ax2.plot(x, Bernstein(x,0,1), 'b', lw = 2)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel('x')
plt.ylabel('y')
plt.title("n = 1; v = 0")

ax3 = plt.subplot(446)
x = np.linspace(0,1,100)
ax3.plot(x, Bernstein(x,1,1), 'b', lw = 2)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel('x')
plt.ylabel('y')
plt.title("n = 1; v = 1")

ax4 = plt.subplot(449)
x = np.linspace(0,1,100)
ax4.plot(x, Bernstein(x,0,2), 'b', lw = 2)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel('x')
plt.ylabel('y')
plt.title("n = 2; v = 0")

ax5 = plt.subplot(4,4,10)
x = np.linspace(0,1,100)
ax5.plot(x, Bernstein(x,1,2), 'b', lw = 2)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel('x')
plt.ylabel('y')
plt.title("n = 2; v = 1")

ax6 = plt.subplot(4,4,11)
x = np.linspace(0,1,100)
ax6.plot(x, Bernstein(x,2,2), 'b', lw = 2)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel('x')
plt.ylabel('y')
plt.title("n = 2; v = 2")

ax7 = plt.subplot(4,4,13)
x = np.linspace(0,1,100)
ax7.plot(x, Bernstein(x,0,3), 'b', lw = 2)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel('x')
plt.ylabel('y')
plt.title("n = 3; v = 0")

ax8 = plt.subplot(4,4,14)
x = np.linspace(0,1,100)
ax8.plot(x, Bernstein(x,1,3), 'b', lw = 2)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel('x')
plt.ylabel('y')
plt.title("n = 3; v = 1")

ax9 = plt.subplot(4,4,15)
x = np.linspace(0,1,100)
ax9.plot(x, Bernstein(x,2,3), 'b', lw = 2)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel('x')
plt.ylabel('y')
plt.title("n = 3; v = 2")

ax10 = plt.subplot(4,4,16)
x = np.linspace(0,1,100)
ax10.plot(x, Bernstein(x,3,3), 'b', lw = 2)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel('x')
plt.ylabel('y')
plt.title("n = 3; v = 3")


plt.tight_layout()

# %% [markdown]
# ### Problem 3
#
# The file `MLB.npy` contains measurements from over 1,000 recent Major League Baseball players, compiled by UCLA.
# Each row in the array represents a different player; the columns are the player’s height (in inches), weight (in pounds), and age (in years), in that order.
#
# Create several visualizations to show the correlations between height, weight, and age in the MLB data set.
# Use at least one scatter plot.
# Adjust the marker size, plot a regression line, change the window limits, and use small multiples where appropriate.

# %%
height, weight, age = np.load("MLB.npy").T

fig, (ax1, ax2) = plt.subplots(1, 2)

ax1.scatter(height, weight, alpha = 0.5, edgecolor = 'none')

ax2.scatter(height, age, alpha = 0.5, edgecolor = 'none')

slope1 = stats.linregress(height, weight)[0]

intercept1 = stats.linregress(height, weight)[1]

slope2 = stats.linregress(height, age)[0]

intercept2 = stats.linregress(height, age)[1]

X1 = np.linspace(60,90,200)
ax1.plot(X1, slope1*X1 + intercept1, 'k')
ax1.set_title("Height vs. Weight")
ax1.set_xlabel("Height")
ax1.set_ylabel("Weight")

ax2.plot(X1, slope2*X1 + intercept2, 'k')
ax2.set_title("Height vs. Age")
ax2.set_xlabel("Height")
ax2.set_ylabel("Age")

plt.tight_layout()

# %% [markdown]
# ### Problem 4
#
# The file `earthquakes.npy` contains data from over 17,000 earthquakes between 2000 and 2010 that were at least a 5 on the Richter scale.
# Each row in the array represents a different earthquake; the columns are the earthquake’s date (as a fraction of the year), magnitude (on the Richter scale), longitude, and latitude, in that order.
#
# Describe the data with at least two better visualizations. Include line plots, scatter plots, and histograms as appropriate.
# Your plots should answer the following questions:
# 1. How many earthquakes happened every year?
# 2. How often do stronger earthquakes happen compared to weaker ones?
# 3. Where do earthquakes happen? Where do the strongest earthquakes happen?
#
# Hint: Use `plt.axis("equal")` or `ax.set_aspect("equal")` to fix the aspect ratio, which may improve comparisons between longitude and latitude.

# %%
years, magnitudes, longitude, latitude = np.load("earthquakes.npy").T

labels = np.array(["2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009"])

Values = np.zeros(10)
for i in range(0, len(years)):
    Year = int(years[i])
    Values[Year - 2000] +=1

positions = np.arange(len(labels))

plt.bar(positions, Values, align = "center")
plt.xticks(positions, labels)
plt.title("Number of Earthquakes Every Year")
plt.show()


labels2 = np.array(["5.0", "5.5", "6.0", "6.5", "7.0", "7.5", "8.0", "8.5", "9.0"])

Values2 = np.zeros(9)
for j in range(0, len(magnitudes)):
    index = int((magnitudes[j]*2)//1)
    Values2[index - 10] +=1

positions2 = np.arange(len(labels2))

plt.bar(positions2, Values2, align = "center")
plt.xticks(positions2, labels2)
plt.title("Strength of Earthquakes")
plt.show()


plt.scatter(longitude, latitude, alpha = 0.5, edgecolor = 'none')
plt.title("Map of Earthquakes")
plt.axis("equal")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

MasksNeeded = [magnitudes[i] > 7 for i in range(0, len(years))]

IndicesNeeded = []



for q in range(0, len(years)):
    if MasksNeeded[q] == True:
        IndicesNeeded.append(q)

NeededLongitudes = [longitude[index] for index in IndicesNeeded]
NeededLatitudes = [latitude[index] for index in IndicesNeeded]

plt.scatter(NeededLongitudes, NeededLatitudes, alpha = 0.5, edgecolor = 'none')
plt.title("Map of Earthquakes with Magnitude > 7.0")
plt.axis("equal")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ### Problem 5
#
# The _Rosenbrock function_ is defined as $$f(x,y)=(1−x)^2 +100(y−x^2)^2$$
# The minimum value of $f$ is $0$, which occurs at the point $(1, 1)$ at the bottom of a steep, banana-shaped valley of the function.
#
# Use a heat map and a contour plot to visualize the Rosenbrock function.
# Also plot the minimizer $(1, 1)$.
# Use a different sequential colormap for each visualization.

# %%
x = np.linspace(0.5, 1.5, 200)
X, Y = np.meshgrid(x,x)
Z = (1-X)**2 + 100*(Y - X**2)**2


fig, ax = plt.subplots(2,2)
cax1 = ax[0,0].pcolormesh(X,Y,Z, cmap = "viridis")
fig.colorbar(cax1, ax = ax[0,0])
ax[0,0].set_title("Heat Map")
cax2 = ax[0,1].contour(X,Y,Z, [0, 0.5, 2.5, 12.5, 62.5, 312.5], cmap = "plasma")
fig.colorbar(cax2, ax = ax[0,1])
ax[0,1].set_title("Contour Map")
cax3 = ax[1,0].contourf(X,Y,Z, [0, 0.5, 2.5, 12.5, 62.5, 312.5], cmap = "inferno")
fig.colorbar(cax3, ax = ax[1,0])
ax[1,0].set_title("Filled Contour Map")
ax[1,1].contour(X,Y,Z, [0, 0.5, 2.5, 12.5, 62.5, 312.5], colors = "white")
cax = ax[1,1].pcolormesh(X,Y,Z, cmap = "magma")
fig.colorbar(cax, ax = ax[1,1])
ax[1,1].set_title("Minimizer")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Problem 6
#
# The file `countries.npy` contains information from 20 different countries.
# Each row in the array represents a different country; the columns are the 2015 population (in millions of people), the 2015 GDP (in billions of US dollars), the average male height (in centimeters), and the average female height (in centimeters), in that order.
#
# Visualize this data set with at least four plots, using at least one scatter plot, one histogram, and one bar chart.
# List the major insights that your visualizations reveal.
#
# (Hint: consider using `np.argsort()` and fancy indexing to sort the data for the bar chart.)

# %%
countries = np.array(
            ["Austria", "Bolivia", "Brazil", "China", "Finland",
             "Germany", "Hungary", "India", "Japan", "North Korea",
             "Montenegro", "Norway", "Peru", "South Korea", "Sri Lanka",
             "Switzerland", "Turkey", "United Kingdom", "United States", "Vietnam"])
population, gdp, male, female = np.load("countries.npy").T



plt.hist(male, bins = 35)
plt.title("Male Height Distribution")
plt.xlabel("Average Male Height (cm)")
plt.xticks(np.arange(155, 195, 5))
plt.ylabel("Number of countries")
plt.tight_layout()
plt.show()


plt.hist(female, bins = 35)
plt.title("Female Height Distribution")
plt.xlabel("Average Female Height (cm)")
plt.xticks(np.arange(140, 175, 5))
plt.ylabel("Number of countries")
plt.tight_layout()
plt.show()


labels = ["Austria", "Bolivia", "Brazil", "China", "Finland",
            "Germany", "Hungary", "India", "Japan", "North Korea",
            "Montenegro", "Norway", "Peru", "South Korea", "Sri Lanka",
            "Switzerland", "Turkey", "United Kingdom", "United States", "Vietnam"]

values = population
positions = np.arange(len(labels))

plt.bar(positions, values, align = "center")
plt.xticks(positions, labels, rotation = 90)
plt.title("Population vs. Country")
plt.xlabel("Population")
plt.ylabel("Population (mil. of people)")
plt.tight_layout()
plt.show()

plt.scatter(population, gdp ,alpha = 0.5, edgecolor = 'none')
plt.title("GDP vs. Population")
plt.xlabel("Population")
plt.ylabel("GDP")
plt.show()
